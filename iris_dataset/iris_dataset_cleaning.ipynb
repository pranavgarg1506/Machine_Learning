# %%
import pandas as pd
import seaborn as sns

# making a dataframe
df = pd.read_csv('iris-data.csv')
# 1.    drooping the null values rows
# 2.    can use mean , median , mode property ti fill the NA values
df = df.dropna(subset=['petal_width_cm'])

# %%
df['class'].replace(['Iris-setossa','versicolor'],['Iris-setosa','Iris-versicolor'], inplace = True)
# print(df['class'].value_counts())

# using only class as Iris-setosa
#final_df = df[df['class'] != 'Iris-virginica']
df_setosa = df[ df['class'] == 'Iris-setosa' ]
df_versicolor = df[ df['class'] == 'Iris-versicolor' ]
df_virginica = df[ df['class'] == 'Iris-virginica' ]


sns.pairplot(df_versicolor, hue='class', height=2.5)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_versicolor.hist(column= 'sepal_length_cm',bins=20, figsize=(10,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fafca133e48>]],
#       dtype=object)

# %%
df_versicolor.loc[final_df.sepal_length_cm < 1, ['sepal_length_cm']] = df_versicolor['sepal_length_cm'] * 100
# Out:
# /home/pranav/.local/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_versicolor.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count        50.000000       50.000000        50.000000       50.000000
# mean          5.936000        2.772000         4.260000        1.326000
# std           0.516171        0.313662         0.469911        0.197753
# min           4.900000        2.000000         3.000000        1.000000
# 25%           5.600000        2.525000         4.000000        1.200000
# 50%           5.900000        2.800000         4.350000        1.300000
# 75%           6.300000        3.000000         4.600000        1.500000
# max           7.000000        3.400000         5.100000        1.800000

# %%
sns.pairplot(df_versicolor.append(df_setosa), hue='class', height=2.5)

# %%
df_setosa = df_setosa.drop(df_setosa[ df_setosa['sepal_width_cm'] < 2.5].index)

# %%
df_setosa['sepal_width_cm'].value_counts()
# Out:
# 3.4    7
# 3.0    6
# 3.5    6
# 3.2    5
# 3.1    4
# 3.8    4
# 3.6    2
# 3.9    2
# 3.3    2
# 3.7    2
# 4.4    1
# 2.3    1
# 4.1    1
# 4.2    1
# 4.0    1
# Name: sepal_width_cm, dtype: int64

# %%
sns.pairplot(df_versicolor.append(df_setosa), hue='class', height=2.5)
